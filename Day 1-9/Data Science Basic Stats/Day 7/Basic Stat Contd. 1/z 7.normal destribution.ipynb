# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
beml = pd.read_csv('D:/DATA SCIENCE/1. Data Scientist/Day 7 -Normal Distribution  Material-Random Variable and Probability/BEML.csv')
glaxo = pd.read_csv('D:/DATA SCIENCE/1. Data Scientist/Day 7 -Normal Distribution  Material-Random Variable and Probability/GLAXO.csv')

# %%
beml.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
glaxo.head()
# Out:
#          Date     Open     High      Low    Last    Close  \
# 0  2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1  2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2  2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3  2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4  2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                9365.0           151.74
# 1               38148.0           622.58
# 2               36519.0           595.09
# 3               12809.0           211.00
# 4               28035.0           459.11

# %%
beml[['Date','Close']]
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
beml = beml.set_index((beml['Date']))

# %%
beml.head()
# Out:
#                   Date    Open     High      Low    Last    Close  \
# Date
# 2010-01-04  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 2010-01-05  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2010-01-06  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 2010-01-07  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 2010-01-08  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2010-01-04              101651.0          1157.18
# 2010-01-05               59504.0           676.47
# 2010-01-06              128908.0          1482.84
# 2010-01-07              117871.0          1352.98
# 2010-01-08              170063.0          1971.42

# %%
plt.plot(beml.Close);
plt.xlabel('Time');
plt.ylabel('Close');

# %%
plt.plot(glaxo.Close);
plt.xlabel('Time');
plt.ylabel('Close');

# %%
beml['gain'] = beml.Close.pct_change(periods = 1)

# %%
beml.head()
# Out:
#                   Date    Open     High      Low    Last    Close  \
# Date
# 2010-01-04  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 2010-01-05  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2010-01-06  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 2010-01-07  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 2010-01-08  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#             Total Trade Quantity  Turnover (Lacs)      gain
# Date
# 2010-01-04              101651.0          1157.18       NaN
# 2010-01-05               59504.0           676.47 -0.000881
# 2010-01-06              128908.0          1482.84  0.004407
# 2010-01-07              117871.0          1352.98  0.003993
# 2010-01-08              170063.0          1971.42 -0.000087

# %%
beml.dropna()
# Out:
#                   Date     Open     High      Low     Last    Close  \
# Date
# 2010-01-05  2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2010-01-06  2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 2010-01-07  2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 2010-01-08  2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# 2010-01-11  2010-01-11  1154.00  1159.45  1134.10  1140.10  1137.00
# ...                ...      ...      ...      ...      ...      ...
# 2016-12-26  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 2016-12-27  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 2016-12-28  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 2016-12-29  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 2016-12-30  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#             Total Trade Quantity  Turnover (Lacs)      gain
# Date
# 2010-01-05               59504.0           676.47 -0.000881
# ...

# %%
plt.figure(figsize = (8, 6));
plt.plot(beml.index, beml.gain);
plt.xlabel('Time');
plt.ylabel('gain');

# %%
sn.distplot(beml.gain, label='Glaxo');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
beml.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1739.000000  1739.000000  1739.000000  1739.000000  1739.000000
# mean    700.233180   713.384704   686.280276   698.413370   698.435221
# std     358.658024   364.165083   351.554420   357.358712   357.429870
# min     129.300000   133.500000   106.000000   128.900000   129.150000
# 25%     371.025000   379.300000   367.525000   370.550000   370.650000
# 50%     685.000000   699.800000   666.750000   683.000000   682.150000
# 75%    1012.000000  1027.800000   997.000000  1011.200000  1010.550000
# max    1569.800000  1612.000000  1540.250000  1555.850000  1558.500000
#
#        Total Trade Quantity  Turnover (Lacs)         gain
# count          1.739000e+03      1739.000000  1738.000000
# mean           2.352309e+05      1682.773985     0.000271
# std            3.561114e+05      2705.430289     0.026431
# min            2.441000e+03        16.130000    -0.133940
# ...

# %%
beml['gain'].head(4).mean()
# Out:
# 0.002506292216579905

# %%
print('Mean:',round(beml.gain.mean(),4))
print('standard deviation:',round(beml.gain.std(),4))
# Out:
# Mean: 0.0003
# standard deviation: 0.0264

# %%
print("MEAN:",round(beml.gain.mean(),5))
print("STANDARD DEVIATION:",round(beml.gain.std(),5))
# Out:
# MEAN: 0.00027
# STANDARD DEVIATION: 0.02643

# %%
from scipy import stats
stats.norm.cdf(-0.02,
loc=beml.gain.mean(),
scale=beml.gain.std())
# Out:
# 0.22155987503755292
